# %%
from PIL import Image
import numpy as np
from matplotlib.pyplot import imshow
# %matplotlib inline

# %%
im=Image.open("./texture_gray.png")
show=lambda x:imshow(np.asarray(x))
im.format,im.size,im.mode
# Out:
# ('PNG', (638, 499), 'RGBA')

# %%
show(im)

# %%
box=(0,0,400,400)
region=im.crop(box)
region.save("./texture_redpot_400.png")

# %%
texture=Image.open('./texture_redpot.png')
show(texture)

# %%
size=(1200,1200)
im=Image.new('RGB',size)
show(im)

# %%
box=(0,0,200,200)
region=texture.crop(box)
show(region)

# %%
im.paste(region,box)
show(im)

# %%
im.paste(region,(200,0,400,200))
show(im)

# %%
im.crop((-10,-10,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=110x110 at 0x1E41990B278>
